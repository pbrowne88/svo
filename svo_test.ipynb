# %%
import nate

# %%
mueller = nate.import_files(['mueller_vol_1.txt', 'mueller_vol_2.txt'])

# %%
mueller.svo()
# Out:
# [[('Political Rallies  ', 'involve', 'U.S. Operations'),
#   ('6', 'involve', 'U.S. Operations'),
#   ('Opposition Toward', 'express', 'WikiLeaks ’s'),
#   ('the Source of', 'dissemble', 'Transfer WikiLeaks Statements'),
#   ('4', 'dissemble', 'Transfer WikiLeaks Statements'),
#   ('the Administration of U.S. Elections', 'target', 'Intrusions'),
#   ('C. Trump Campaign', 'target', 'Intrusions'),
#   ('J.D. Gordon', 'invite', 'Convention Contacts with'),
#   ('Breakfast', 'invite', 'Convention Contacts with'),
#   ('Ambassador Residence  ', 'invite', 'Convention Contacts with'),
#   ('the Campaign    ii', 'join', 'the i. Paul Manafort'),
#   ('Seychelles Meeting with', 'arrange', 'c. Erik Prince'),
#   ('the InvestigationIntroduction', 'interview', 'Others'),
#   ('the Attorney General', 'submit', 'IThis report'),
#   ('the Attorney General', 'provide', 'he'),
#   ('a confidential report', 'provide', 'he'),
#   ('prosecution decisions Counsel', 'explain', 'a confidential report'),
# ...
